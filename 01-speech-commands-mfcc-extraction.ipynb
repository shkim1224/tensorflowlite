# %%
from os import listdir
from os.path import isdir, join
import librosa
import random
import numpy as np
import matplotlib.pyplot as plt
import python_speech_features

# %%
# Dataset path and view possible targets
dataset_path = 'F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset'
for name in listdir(dataset_path):
    if isdir(join(dataset_path, name)):
        print(name)
# Out:
# backward
# bed
# bird
# cat
# dog
# down
# eight
# five
# follow
# forward
# four
# go
# happy
# house
# learn
# left
# marvin
# nine
# no
# off
# on
# one
# right
# seven
# sheila
# six
# stop
# three
# tree
# two
# up
# visual
# wow
# yes
# zero
# _background_noise_

# %%
# Create an all targets list
all_targets = [name for name in listdir(dataset_path) if isdir(join(dataset_path, name))]
print(all_targets)
# Out:
# ['backward', 'bed', 'bird', 'cat', 'dog', 'down', 'eight', 'five', 'follow', 'forward', 'four', 'go', 'happy', 'house', 'learn', 'left', 'marvin', 'nine', 'no', 'off', 'on', 'one', 'right', 'seven', 'sheila', 'six', 'stop', 'three', 'tree', 'two', 'up', 'visual', 'wow', 'yes', 'zero', '_background_noise_']

# %%
# Leave off background noise set
all_targets.remove('_background_noise_')
print(all_targets)
# Out:
# ['backward', 'bed', 'bird', 'cat', 'dog', 'down', 'eight', 'five', 'follow', 'forward', 'four', 'go', 'happy', 'house', 'learn', 'left', 'marvin', 'nine', 'no', 'off', 'on', 'one', 'right', 'seven', 'sheila', 'six', 'stop', 'three', 'tree', 'two', 'up', 'visual', 'wow', 'yes', 'zero']

# %%
# See how many files are in each
num_samples = 0
for target in all_targets:
    print(len(listdir(join(dataset_path, target))))
    num_samples += len(listdir(join(dataset_path, target)))
print('Total samples:', num_samples)
# Out:
# 1664
# 2014
# 2064
# 2031
# 2128
# 3917
# 3787
# 4052
# 1579
# 1557
# 3728
# 3880
# 2054
# 2113
# 1575
# 3801
# 2100
# 3934
# 3941
# 3745
# 3845
# 3890
# 3778
# 3998
# 2022
# 3860
# 3872
# 3727
# 1759
# 3880
# 3723
# 1592
# 2123
# 4044
# 4052
# Total samples: 105829

# %%
# Settings
target_list = all_targets
feature_sets_file = 'all_targets_mfcc_sets.npz'
perc_keep_samples = 1.0 # 1.0 is keep all samples
val_ratio = 0.1
test_ratio = 0.1
sample_rate = 8000
num_mfcc = 16
len_mfcc = 16

# %%
# Create list of filenames along with ground truth vector (y)
filenames = []
y = []
for index, target in enumerate(target_list):
    print(join(dataset_path, target))
    filenames.append(listdir(join(dataset_path, target)))
    y.append(np.ones(len(filenames[index])) * index)
# Out:
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\backward
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\bed
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\bird
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\cat
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\dog
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\down
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\eight
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\five
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\follow
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\forward
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\four
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\go
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\happy
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\house
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\learn
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\left
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\marvin
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\nine
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\no
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\off
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\on
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\one
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\right
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\seven
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\sheila
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\six
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\stop
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\three
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\tree
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\two
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\up
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\visual
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\wow
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\yes
# F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\zero

# %%
# Check ground truth Y vector
print(y)
for item in y:
    print(len(item))
# Out:
# [array([0., 0., 0., ..., 0., 0., 0.]), array([1., 1., 1., ..., 1., 1., 1.]), array([2., 2., 2., ..., 2., 2., 2.]), array([3., 3., 3., ..., 3., 3., 3.]), array([4., 4., 4., ..., 4., 4., 4.]), array([5., 5., 5., ..., 5., 5., 5.]), array([6., 6., 6., ..., 6., 6., 6.]), array([7., 7., 7., ..., 7., 7., 7.]), array([8., 8., 8., ..., 8., 8., 8.]), array([9., 9., 9., ..., 9., 9., 9.]), array([10., 10., 10., ..., 10., 10., 10.]), array([11., 11., 11., ..., 11., 11., 11.]), array([12., 12., 12., ..., 12., 12., 12.]), array([13., 13., 13., ..., 13., 13., 13.]), array([14., 14., 14., ..., 14., 14., 14.]), array([15., 15., 15., ..., 15., 15., 15.]), array([16., 16., 16., ..., 16., 16., 16.]), array([17., 17., 17., ..., 17., 17., 17.]), array([18., 18., 18., ..., 18., 18., 18.]), array([19., 19., 19., ..., 19., 19., 19.]), array([20., 20., 20., ..., 20., 20., 20.]), array([21., 21., 21., ..., 21., 21., 21.]), array([22., 22., 22., ..., 22., 22., 22.]), array([23., 23., 23., ..., 23., 23., 23.]), array([24., 24., 24., ..., 24., 24., 24.]), array([25., 25., 25., ..., 25., 25., 25.]), array([26., 26., 26., ..., 26., 26., 26.]), array([27., 27., 27., ..., 27., 27., 27.]), array([28., 28., 28., ..., 28., 28., 28.]), array([29., 29., 29., ..., 29., 29., 29.]), array([30., 30., 30., ..., 30., 30., 30.]), array([31., 31., 31., ..., 31., 31., 31.]), array([32., 32., 32., ..., 32., 32., 32.]), array([33., 33., 33., ..., 33., 33., 33.]), array([34., 34., 34., ..., 34., 34., 34.])]
# 1664
# 2014
# 2064
# 2031
# 2128
# 3917
# 3787
# 4052
# 1579
# 1557
# 3728
# 3880
# 2054
# 2113
# 1575
# 3801
# 2100
# 3934
# 3941
# 3745
# 3845
# 3890
# 3778
# 3998
# 2022
# 3860
# 3872
# 3727
# 1759
# 3880
# 3723
# 1592
# 2123
# 4044
# 4052

# %%
# Flatten filename and y vectors
filenames = [item for sublist in filenames for item in sublist]
y = [item for sublist in y for item in sublist]

# %%
# Associate filenames with true output and shuffle
filenames_y = list(zip(filenames, y))
random.shuffle(filenames_y)
filenames, y = zip(*filenames_y)

# %%
# Only keep the specified number of samples (shorter extraction/training)
print(len(filenames))
filenames = filenames[:int(len(filenames) * perc_keep_samples)]
print(len(filenames))
# Out:
# 105829
# 105829

# %%
# Calculate validation and test set sizes
val_set_size = int(len(filenames) * val_ratio)
test_set_size = int(len(filenames) * test_ratio)

# %%
# Break dataset apart into train, validation, and test sets
filenames_val = filenames[:val_set_size]
filenames_test = filenames[val_set_size:(val_set_size + test_set_size)]
filenames_train = filenames[(val_set_size + test_set_size):]

# %%
# Break y apart into train, validation, and test sets
y_orig_val = y[:val_set_size]
y_orig_test = y[val_set_size:(val_set_size + test_set_size)]
y_orig_train = y[(val_set_size + test_set_size):]

# %%
# Function: Create MFCC from given path
def calc_mfcc(path):
    
    # Load wavefile
    signal, fs = librosa.load(path, sr=sample_rate)
    
    # Create MFCCs from sound clip
    mfccs = python_speech_features.base.mfcc(signal, 
                                            samplerate=fs,
                                            winlen=0.256,
                                            winstep=0.050,
                                            numcep=num_mfcc,
                                            nfilt=26,
                                            nfft=2048,
                                            preemph=0.0,
                                            ceplifter=0,
                                            appendEnergy=False,
                                            winfunc=np.hanning)
    return mfccs.transpose()

# %%
# TEST: Construct test set by computing MFCC of each WAV file
prob_cnt = 0
x_test = []
y_test = []
for index, filename in enumerate(filenames_train):
    
    # Stop after 500
    if index >= 500:
        break
    
    # Create path from given filename and target item
    path = join(dataset_path, target_list[int(y_orig_train[index])], 
                filename)
    
    # Create MFCCs
    mfccs = calc_mfcc(path)
    
    if mfccs.shape[1] == len_mfcc:
        x_test.append(mfccs)
        y_test.append(y_orig_train[index])
    else:
        print('Dropped:', index, mfccs.shape)
        prob_cnt += 1
# Out:
# Dropped: 6 (16, 8)
# Dropped: 22 (16, 7)
# Dropped: 38 (16, 11)
# Dropped: 41 (16, 8)
# Dropped: 48 (16, 10)
# Dropped: 50 (16, 13)
# Dropped: 59 (16, 15)
# Dropped: 64 (16, 15)
# Dropped: 91 (16, 15)
# Dropped: 92 (16, 7)
# Dropped: 94 (16, 14)
# Dropped: 98 (16, 11)
# Dropped: 106 (16, 13)
# Dropped: 118 (16, 15)
# Dropped: 119 (16, 14)
# Dropped: 121 (16, 10)
# Dropped: 127 (16, 11)
# Dropped: 133 (16, 15)
# Dropped: 162 (16, 9)
# Dropped: 168 (16, 7)
# Dropped: 176 (16, 11)
# Dropped: 177 (16, 14)
# Dropped: 186 (16, 15)
# Dropped: 203 (16, 14)
# Dropped: 204 (16, 12)
# Dropped: 240 (16, 15)
# Dropped: 252 (16, 6)
# Dropped: 253 (16, 13)
# Dropped: 275 (16, 10)
# Dropped: 283 (16, 13)
# Dropped: 291 (16, 13)
# Dropped: 305 (16, 8)
# Dropped: 306 (16, 12)
# Dropped: 322 (16, 9)
# Dropped: 334 (16, 14)
# Dropped: 361 (16, 8)
# Dropped: 363 (16, 11)
# Dropped: 382 (16, 15)
# Dropped: 395 (16, 15)
# Dropped: 413 (16, 12)
# Dropped: 445 (16, 9)
# Dropped: 446 (16, 11)
# Dropped: 462 (16, 11)
# Dropped: 479 (16, 13)

# %%
print('% of problematic samples:', prob_cnt / 500)
# Out:
# % of problematic samples: 0.088

# %%
# TEST: Test shorter MFCC
# !pip install playsound
from playsound import playsound

idx = 13

# Create path from given filename and target item
path = join(dataset_path, target_list[int(y_orig_train[idx])], 
            filenames_train[idx])

# Create MFCCs
mfccs = calc_mfcc(path)
print("MFCCs:", mfccs)

# Plot MFCC
fig = plt.figure()
plt.imshow(mfccs, cmap='inferno', origin='lower')

# TEST: Play problem sounds
print(target_list[int(y_orig_train[idx])])
playsound(path)
# Out:
#     Error 259 for command:
#         play "F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\nine\a4e8a997_nohash_0.wav" wait
#     지정한 명령 매개 변수를 드라이버가 인식할 수 없습니다.
#
#     Error 305 for command:
#         close "F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\nine\a4e8a997_nohash_0.wav"
#     문자열을 따옴표로 닫은 후에는 문자를 더 지정할 수 없습니다.
# Failed to close the file: "F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset
#   -1.49432681e-01 -1.77686771e-02  1.89359656e-01  6.76421349e-01]
#  [-7.72510202e-01 -3.67678247e-01  1.26010558e+00  1.61288491e+00
#    1.42116848e+00  1.16934142e+00  1.22529715e+00  1.11517519e+00
#    7.47546669e-01  4.72854605e-01 -1.71661492e-01 -2.50729566e-01
#    3.58431516e-01  1.06688879e+00  1.10124634e+00  1.34820027e+00]
#  [-1.23670422e-01 -1.54297766e-01 -4.16268907e-01 -8.22006431e-01
#   -6.35695750e-01 -2.74012859e-01 -2.60350467e-01 -4.87226069e-01
#   -5.83143147e-01 -8.06621835e-01 -7.59114620e-01 -3.54417602e-01
#   -2.59763320e-01 -2.36117284e-01 -3.77375066e-01 -3.66567204e-02]
#  [ 2.48389541e-01 -2.97267410e-01 -4.43560611e-01 -1.81457739e-01
#    3.41536572e-01  6.13762831e-01  5.66449252e-01  2.75705575e-01
#    2.25549885e-02  4.08120336e-01  1.16542504e+00  6.04749497e-01
#   -6.69902569e-01 -9.58761285e-01 -8.02119047e-01 -4.33373483e-01]
#  [-3.36702474e-01  2.32076109e-01  1.96042640e-01 -3.49649057e-02
#   -5.75361877e-01 -8.47912521e-01 -7.90876823e-01 -5.11405773e-01
#   -3.11972300e-01 -4.05867479e-01 -8.72881203e-01 -4.48738773e-01
#    2.23967012e-01 -2.09033344e-01 -4.64633982e-01 -5.05972858e-02]
#  [ 6.08440756e-01  5.68335806e-01  4.85066586e-01  6.52768144e-01
#    5.69691634e-01  3.28196691e-01  1.13504802e-01 -5.20790326e-01
#   -9.07166411e-01 -8.95530270e-01 -5.81209232e-01  1.02786138e-01
#    6.91539093e-01  6.08793509e-01  4.90430871e-01  7.31003544e-01]
#  [ 1.61881836e-01 -2.46347261e-01 -1.81557315e-01 -2.45734853e-02
#    1.25476029e-01  3.43945280e-01  3.91734465e-01  4.51674145e-01
#    3.39640054e-01  1.41083460e-01  3.98357003e-01  3.47100174e-02
#   -5.70634279e-01 -6.05234371e-01 -7.97847062e-01 -5.67375265e-01]]
# nine
# ---------------------------------------------------------------------------
# PlaysoundException                        Traceback (most recent call last)
# <ipython-input-26-0864a6659860> in <module>
#      19 # TEST: Play problem sounds
#      20 print(target_list[int(y_orig_train[idx])])
# ---> 21 playsound(path)
#
# f:\Anaconda3\envs\yolov3_test\lib\site-packages\playsound.py in _playsoundWin(sound, block)
#      71         logger.debug('Starting')
#      72         winCommand(u'open {}'.format(sound))
# ---> 73         winCommand(u'play {}{}'.format(sound, ' wait' if block else ''))
#      74         logger.debug('Returning')
#      75     finally:
#
# f:\Anaconda3\envs\yolov3_test\lib\site-packages\playsound.py in winCommand(*command)
#      62                                 '\n    ' + errorBuffer.raw.decode('utf-16').rstrip('\0'))
#      63             logger.error(exceptionMessage)
# ---> 64             raise PlaysoundException(exceptionMessage)
#      65         return buf.value
#      66
#
# PlaysoundException:
#     Error 259 for command:
#         play "F:/2021_2_lecture/tensorflowLite_test/speech_commands_dataset\nine\a4e8a997_nohash_0.wav" wait
#     지정한 명령 매개 변수를 드라이버가 인식할 수 없습니다.

# %%
# Function: Create MFCCs, keeping only ones of desired length
def extract_features(in_files, in_y):
    prob_cnt = 0
    out_x = []
    out_y = []
        
    for index, filename in enumerate(in_files):
    
        # Create path from given filename and target item
        path = join(dataset_path, target_list[int(in_y[index])], 
                    filename)
        
        # Check to make sure we're reading a .wav file
        if not path.endswith('.wav'):
            continue

        # Create MFCCs
        mfccs = calc_mfcc(path)

        # Only keep MFCCs with given length
        if mfccs.shape[1] == len_mfcc:
            out_x.append(mfccs)
            out_y.append(in_y[index])
        else:
            print('Dropped:', index, mfccs.shape)
            prob_cnt += 1
            
    return out_x, out_y, prob_cnt

# %%
# Create train, validation, and test sets
x_train, y_train, prob = extract_features(filenames_train, 
                                          y_orig_train)
print('Removed percentage:', prob / len(y_orig_train))
x_val, y_val, prob = extract_features(filenames_val, y_orig_val)
print('Removed percentage:', prob / len(y_orig_val))
x_test, y_test, prob = extract_features(filenames_test, y_orig_test)
print('Removed percentage:', prob / len(y_orig_test))
# Out:
# Dropped: 6 (16, 8)
# Dropped: 22 (16, 7)
# Dropped: 38 (16, 11)
# Dropped: 41 (16, 8)
# Dropped: 48 (16, 10)
# Dropped: 50 (16, 13)
# Dropped: 59 (16, 15)
# Dropped: 64 (16, 15)
# Dropped: 91 (16, 15)
# Dropped: 92 (16, 7)
# Dropped: 94 (16, 14)
# Dropped: 98 (16, 11)
# Dropped: 106 (16, 13)
# Dropped: 118 (16, 15)
# Dropped: 119 (16, 14)
# Dropped: 121 (16, 10)
# Dropped: 127 (16, 11)
# Dropped: 133 (16, 15)
# Dropped: 162 (16, 9)
# Dropped: 168 (16, 7)
# Dropped: 176 (16, 11)
# Dropped: 177 (16, 14)
# Dropped: 186 (16, 15)
# Dropped: 203 (16, 14)
# Dropped: 204 (16, 12)
# Dropped: 240 (16, 15)
# Dropped: 252 (16, 6)
# Dropped: 253 (16, 13)
# Dropped: 275 (16, 10)
# Dropped: 283 (16, 13)
# Dropped: 291 (16, 13)
# Dropped: 305 (16, 8)
# Dropped: 306 (16, 12)
# Dropped: 322 (16, 9)
# Dropped: 334 (16, 14)
# Dropped: 361 (16, 8)
# Dropped: 363 (16, 11)
# Dropped: 382 (16, 15)
# Dropped: 395 (16, 15)
# Dropped: 413 (16, 12)
# Dropped: 445 (16, 9)
# Dropped: 446 (16, 11)
# Dropped: 462 (16, 11)
# Dropped: 479 (16, 13)
# Dropped: 539 (16, 13)
# Dropped: 547 (16, 12)
# Dropped: 552 (16, 11)
# Dropped: 562 (16, 13)
# Dropped: 567 (16, 15)
# Dropped: 572 (16, 13)
# Dropped: 604 (16, 14)
# Dropped: 611 (16, 4)
# Dropped: 613 (16, 11)
# Dropped: 634 (16, 11)
# Dropped: 642 (16, 7)
# Dropped: 700 (16, 13)
# Dropped: 712 (16, 10)
# Dropped: 722 (16, 11)
# Dropped: 737 (16, 14)
# Dropped: 1579 (16, 13)
# Dropped: 1607 (16, 11)
# Dropped: 1619 (16, 7)
# Dropped: 1622 (16, 15)
# Dropped: 1629 (16, 15)
# Dropped: 1639 (16, 11)
# Dropped: 1649 (16, 14)
# Dropped: 1654 (16, 14)
# Dropped: 1660 (16, 12)
# Dropped: 1667 (16, 7)
# Dropped: 1671 (16, 15)
# Dropped: 1676 (16, 13)
# Dropped: 1681 (16, 12)
# Dropped: 1694 (16, 11)
# Dropped: 1695 (16, 9)
# Dropped: 1709 (16, 11)
# Dropped: 1712 (16, 13)
# Dropped: 1717 (16, 7)
# Dropped: 1738 (16, 14)
# Dropped: 1743 (16, 14)
# Dropped: 1759 (16, 12)
# Dropped: 1778 (16, 11)
# Dropped: 1785 (16, 8)
# Dropped: 1786 (16, 10)
# Dropped: 1791 (16, 7)
# Dropped: 1793 (16, 12)
# Dropped: 1796 (16, 8)
# Dropped: 1823 (16, 15)
# Dropped: 1835 (16, 13)
# Dropped: 1876 (16, 11)
# Dropped: 1898 (16, 10)
# Dropped: 1905 (16, 7)
# Dropped: 1916 (16, 15)
# Dropped: 1942 (16, 14)
# Dropped: 1947 (16, 10)
# Dropped: 1949 (16, 15)
# Dropped: 1974 (16, 13)
# Dropped: 1978 (16, 11)
# Dropped: 1982 (16, 12)
# Dropped: 2021 (16, 10)
# Dropped: 2024 (16, 13)
# Dropped: 2049 (16, 10)
# Dropped: 2050 (16, 14)
# Dropped: 2053 (16, 11)
# Dropped: 2060 (16, 13)
# Dropped: 2091 (16, 10)
# Dropped: 2124 (16, 15)
# Dropped: 2135 (16, 8)
# Dropped: 2153 (16, 11)
# Dropped: 2179 (16, 13)
# Dropped: 2184 (16, 15)
# Dropped: 2227 (16, 10)
# Dropped: 2239 (16, 11)
# Dropped: 2242 (16, 13)
# Dropped: 2249 (16, 15)
# Dropped: 2251 (16, 10)
# Dropped: 2256 (16, 11)
# Dropped: 2276 (16, 11)
# Dropped: 2284 (16, 10)
# Dropped: 2310 (16, 11)
# Dropped: 2320 (16, 12)
# Dropped: 2331 (16, 13)
# Dropped: 2332 (16, 14)
# Dropped: 2337 (16, 12)
# Dropped: 2361 (16, 12)
# Dropped: 2371 (16, 14)
# Dropped: 2383 (16, 14)
# Dropped: 2392 (16, 8)
# Dropped: 2405 (16, 14)
# Dropped: 2419 (16, 9)
# Dropped: 2425 (16, 4)
# Dropped: 2427 (16, 15)
# Dropped: 2450 (16, 15)
# Dropped: 2459 (16, 8)
# Dropped: 2462 (16, 11)
# Dropped: 2489 (16, 13)
# Dropped: 2503 (16, 14)
# Dropped: 2520 (16, 12)
# Dropped: 2529 (16, 13)
# Dropped: 2545 (16, 13)
# Dropped: 2554 (16, 13)
# Dropped: 2577 (16, 15)
# Dropped: 2585 (16, 10)
# Dropped: 2606 (16, 10)
# Dropped: 2610 (16, 8)
# Dropped: 2622 (16, 15)
# Dropped: 2667 (16, 8)
# Dropped: 3642 (16, 14)
# Dropped: 3645 (16, 15)
# Dropped: 3666 (16, 10)
# Dropped: 3669 (16, 11)
# Dropped: 3716 (16, 15)
# Dropped: 3718 (16, 15)
# Dropped: 3727 (16, 8)
# Dropped: 3737 (16, 11)
# Dropped: 3743 (16, 15)
# Dropped: 3760 (16, 9)
# Dropped: 3767 (16, 6)
# Dropped: 3798 (16, 11)
# Dropped: 3804 (16, 12)
# Dropped: 3808 (16, 14)
# Dropped: 3813 (16, 14)
# Dropped: 3814 (16, 7)
# Dropped: 3841 (16, 13)
# Dropped: 3846 (16, 12)
# Dropped: 3862 (16, 9)
# Dropped: 3885 (16, 15)
# Dropped: 3889 (16, 13)
# Dropped: 3895 (16, 14)
# Dropped: 3899 (16, 12)
# Dropped: 3902 (16, 13)
# Dropped: 3912 (16, 7)
# Dropped: 3932 (16, 12)
# Dropped: 3956 (16, 11)
# Dropped: 3958 (16, 15)
# Dropped: 3961 (16, 7)
# Dropped: 3991 (16, 12)
# Dropped: 4007 (16, 15)
# Dropped: 4044 (16, 7)
# Dropped: 4060 (16, 7)
# Dropped: 4063 (16, 11)
# Dropped: 4075 (16, 10)
# Dropped: 4078 (16, 15)
# Dropped: 4083 (16, 11)
# Dropped: 4092 (16, 14)
# Dropped: 4129 (16, 15)
# Dropped: 4130 (16, 14)
# Dropped: 4148 (16, 13)
# Dropped: 4164 (16, 11)
# Dropped: 4165 (16, 14)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-95a048d19886> in <module>
#       1 # Create train, validation, and test sets
#       2 x_train, y_train, prob = extract_features(filenames_train,
# ----> 3                                           y_orig_train)
#       4 print('Removed percentage:', prob / len(y_orig_train))
#       5 x_val, y_val, prob = extract_features(filenames_val, y_orig_val)
#
# <ipython-input-27-5499b448bca3> in extract_features(in_files, in_y)
#      16
#      17         # Create MFCCs
# ---> 18         mfccs = calc_mfcc(path)
#      19
#      20         # Only keep MFCCs with given length
#
# <ipython-input-20-6bcb08eac9a6> in calc_mfcc(path)
#       3
#       4     # Load wavefile
# ----> 5     signal, fs = librosa.load(path, sr=sample_rate)
#       6
#       7     # Create MFCCs from sound clip
#
# f:\Anaconda3\envs\yolov3_test\lib\site-packages\librosa\core\audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     173
#     174     if sr is not None:
# --> 175         y = resample(y, sr_native, sr, res_type=res_type)
#     176
#     177     else:
#
# f:\Anaconda3\envs\yolov3_test\lib\site-packages\librosa\core\audio.py in resample(y, orig_sr, target_sr, res_type, fix, scale, **kwargs)
#     602         y_hat = soxr.resample(y.T, orig_sr, target_sr, quality=res_type).T
#     603     else:
# --> 604         y_hat = resampy.resample(y, orig_sr, target_sr, filter=res_type, axis=-1)
#     605
#     606     if fix:
#
# f:\Anaconda3\envs\yolov3_test\lib\site-packages\resampy\core.py in resample(x, sr_orig, sr_new, axis, filter, **kwargs)
#     118     x_2d = x.swapaxes(0, axis).reshape((x.shape[axis], -1))
#     119     y_2d = y.swapaxes(0, axis).reshape((y.shape[axis], -1))
# --> 120     resample_f(x_2d, y_2d, sample_ratio, interp_win, interp_delta, precision)
#     121
#     122     return y
#
# KeyboardInterrupt:

# %%
# Save features and truth vector (y) sets to disk
np.savez(feature_sets_file, 
         x_train=x_train, 
         y_train=y_train, 
         x_val=x_val, 
         y_val=y_val, 
         x_test=x_test, 
         y_test=y_test)

# %%
# TEST: Load features
feature_sets = np.load(feature_sets_file)
feature_sets.files
# Out:
# ['x_train', 'y_train', 'x_val', 'y_val', 'x_test', 'y_test']

# %%
len(feature_sets['x_train'])
# Out:
# 77559

# %%
print(feature_sets['y_val'])
# Out:
# [29. 23. 10. ... 24.  5.  7.]

# %% [markdown]
# Test shorter MFCC

# %%
# TEST: Test shorter MFCC
# !pip install playsound

from playsound import playsound

idx = 13

# Create path from given filename and target item
path = join(dataset_path, target_list[int(y_orig_train[idx])], 
            filenames_train[idx])

# Create MFCCs
mfccs = calc_mfcc(path)
print("MFCCs:", mfccs)

# Plot MFCC
fig = plt.figure()
plt.imshow(mfccs, cmap='inferno', origin='lower')

# TEST: Play problem sounds
print(target_list[int(y_orig_train[idx])])
playsound(path)
# Out:
# MFCCs: [[-5.60205255e+01 -5.57326941e+01 -5.53180150e+01 -5.46549573e+01
#   -5.49967940e+01 -5.61930837e+01 -4.70917064e+01 -2.13797062e+01
#   -8.08488181e+00 -2.86336546e+00 -2.64543555e+00 -6.79119668e+00
#   -1.45270278e+01 -2.12873240e+01 -2.66429811e+01 -3.40868181e+01]
#  [ 4.20868259e+00  4.00463624e+00  3.86272572e+00  4.01374470e+00
#    4.11240176e+00  4.10765803e+00  9.45592672e+00  7.02840901e+00
#    4.65898039e+00  4.15270383e+00  4.95897033e+00  7.20784610e+00
#    1.05852635e+01  1.16684823e+01  1.06626905e+01  9.40551109e+00]
#  [ 6.89918690e-02  1.92887818e-02  6.89534729e-02 -1.42870040e-01
#   -4.94959044e-01 -5.37524873e-01 -2.23996437e+00 -1.39072844e+00
#   -1.38889553e+00 -1.07087106e+00 -2.46958678e-01  1.16634108e+00
#    2.95603099e+00  5.67008672e+00  6.67792476e+00  4.78517423e+00]
#  [ 1.95747360e+00  1.38376083e+00  1.56859373e+00  1.74444909e+00
#    1.52852998e+00  1.62101000e+00 -2.46246287e+00 -5.40039282e+00
#   -4.37798973e+00 -3.32614978e+00 -2.15337305e+00 -6.26589737e-01
#    1.83009391e+00  3.26363562e+00  3.43776332e+00  3.92647406e+00]
#  [ 1.41782873e+00  6.60552254e-01  5.24217121e-01  2.61324985e-01
#    4.02366669e-01  8.53107651e-01 -8.59810363e-01  5.13203361e-01
#    7.50233375e-01  8.97010195e-01  4.57813856e-01 -9.47288366e-01
#   -2.66260022e+00 -2.74353002e+00 -7.48810520e-01  1.69514227e+00]
#  [ 1.21878181e+00  1.05487581e+00  7.12607748e-01  4.50309761e-02
#    1.40120523e-01  6.24402370e-01 -1.37740439e+00 -9.06928466e-01
#   -1.35901504e+00 -1.89781726e+00 -2.52776527e+00 -3.39103822e+00
#   -3.73996507e+00 -4.27979050e+00 -4.65246208e+00 -3.56383589e+00]
#  [ 7.71312581e-01  7.81715146e-01  7.09041867e-01  5.67683450e-01
#    7.57980447e-01  1.42645908e+00 -2.97400381e+00 -5.04757116e+00
#   -4.78710498e+00 -4.62619334e+00 -4.37491178e+00 -3.80015116e+00
#   -3.11248421e+00 -2.75944202e+00 -2.68663196e+00 -1.56018436e+00]
